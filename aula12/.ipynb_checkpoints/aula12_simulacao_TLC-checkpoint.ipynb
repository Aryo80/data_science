# %% [markdown]
# # Teorema Central do Limite
#
# Neste notebook vamos simular coletar amostras de várias distribuições diferentes (normal, gamma, uniforme, loggamma) e estudar as propriedades da variância e da média retiradas das amostras.

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd
from scipy.stats import norm, gamma, uniform, loggamma
# %matplotlib inline

# %% [markdown]
# ___
# ## Distribuição da Média Amostral a partir de X com distribuição Gamma

# %%
x = np.linspace(0,10,100)
y = gamma.pdf(x,a=2)
plt.plot(x,y)
plt.axvline(2, color='r')
 # gera 100.000 amostras aleatórias de uma gamma com parâmetro de forma a=2
data = gamma.rvs(a=2, size=100000)
plt.hist(data, bins=20, normed=True)
print('X segue uma distribuição Gamma')
print('Média de X:', "%6.3f"%np.mean(data))
print('Variância de X:', "%6.3f"%np.var(data))
print ('-' * 20)
# Out:
# X segue uma distribuição Gamma
# Média de X:  2.003
# Variância de X:  2.009
# --------------------

# %% [markdown]
# ### Construção da distribuição da Média Amostral alterando tamanho amostral n
#
# Note que tamanho amostral não é o **número de amostras**, mas sim o **número de elementos que compõem cada amostra**. Nos exemplos abaixo criaremos *sempre* 100.000 amostras, mas variaremos o número de elementos que compõem cada amostra de acordo com a lista `[2, 4, 10, 30, 50, 100]`

# %%
for n in [2, 4, 10, 30, 50, 100]:
    # Gera 100.000 amostras de tamanho n
    sampling = gamma.rvs(a=2,size=(100000,n))
    mean_of_sample = np.mean(sampling,axis=1)
    mean_of_mean = np.mean(mean_of_sample)
    dp_of_mean = np.std(mean_of_sample,ddof=1)
    plt.figure()
    plt.hist(mean_of_sample,bins=20,normed=True)
    x = np.linspace(0,6,100)
    y = norm.pdf(x,loc=mean_of_mean,scale=dp_of_mean)
    plt.plot(x,y,'r')
    plt.title('Tamanho da amostra: n='+str(n))
    print('Tamanho da amostra: n=',n)
    print('Média das médias amostrais:', "%6.3f"%mean_of_mean)
    print('Variância das médias amostrais:', "%6.3f"%dp_of_mean**2)
    print ('-' * 20)
# Out:
# Tamanho da amostra: n= 2
# Média das médias amostrais:  2.007
# Variância das médias amostrais:  1.008
# --------------------
# Tamanho da amostra: n= 4
# Média das médias amostrais:  2.000
# Variância das médias amostrais:  0.500
# --------------------
# Tamanho da amostra: n= 10
# Média das médias amostrais:  2.002
# Variância das médias amostrais:  0.200
# --------------------
# Tamanho da amostra: n= 30
# Média das médias amostrais:  2.000
# Variância das médias amostrais:  0.066
# --------------------
# Tamanho da amostra: n= 50
# Média das médias amostrais:  2.000
# Variância das médias amostrais:  0.040
# --------------------
# Tamanho da amostra: n= 100
# Média das médias amostrais:  2.000
# Variância das médias amostrais:  0.020
# --------------------

# %% [markdown]
# ___
# ## Distribuição da Média Amostral a partir de X com distribuição Uniforme

# %%
x = np.linspace(0,10,100)
y = uniform.pdf(x,0,10)
plt.plot(x,y)
plt.axvline(5, color='r')
data = uniform.rvs(0,10, size=100000)
plt.hist(data, bins=20, normed=True)
print('X segue uma distribuição Uniforme')
print('Média de X:', "%6.3f"%np.mean(data))
print('Variância de X:', "%6.3f"%np.var(data))
print ('-' * 20)
# Out:
# X segue uma distribuição Uniforme
# Média de X:  4.993
# Variância de X:  8.314
# --------------------

# %% [markdown]
# **Construção da distribuição da Média Amostral alterando tamanho amostral n**

# %%
for n in [2, 4, 10, 30, 50, 100]:
    sampling = uniform.rvs(0,10,size=(100000,n))
    mean_of_sample = np.mean(sampling,1)
    mean_of_mean = np.mean(mean_of_sample)
    dp_of_mean = np.std(mean_of_sample,ddof=1)
    plt.figure()
    plt.hist(mean_of_sample,bins=20,normed=True)
    x = np.linspace(0,10,100)
    y = norm.pdf(x,loc=mean_of_mean,scale=dp_of_mean)
    plt.plot(x,y,'r')
    plt.title('Tamanho da amostra: n='+str(n))
    print('Tamanho da amostra: n=',n)
    print('Média das médias amostrais:', "%6.3f"%mean_of_mean)
    print('Variância das médias amostrais:', "%6.3f"%dp_of_mean**2)
    print ('-' * 20)
# Out:
# Tamanho da amostra: n= 2
# Média das médias amostrais:  4.992
# Variância das médias amostrais:  4.182
# --------------------
# Tamanho da amostra: n= 4
# Média das médias amostrais:  4.994
# Variância das médias amostrais:  2.072
# --------------------
# Tamanho da amostra: n= 10
# Média das médias amostrais:  5.001
# Variância das médias amostrais:  0.837
# --------------------
# Tamanho da amostra: n= 30
# Média das médias amostrais:  4.998
# Variância das médias amostrais:  0.278
# --------------------
# Tamanho da amostra: n= 50
# Média das médias amostrais:  5.000
# Variância das médias amostrais:  0.168
# --------------------
# Tamanho da amostra: n= 100
# Média das médias amostrais:  5.000
# Variância das médias amostrais:  0.083
# --------------------

# %% [markdown]
# ___
# ## Distribuição da Média Amostral a partir de X com distribuição LogGamma

# %%
x = np.linspace(1390,1450,15)
y = loggamma.pdf(x,0.08,1440,0.7)
plt.plot(x,y)
plt.axvline(1430, color='r')
data = loggamma.rvs(0.08,1440,0.7, size=100000)
plt.hist(data, bins=20, normed=True)
print('X segue uma distribuição LogGamma')
print('Média de X:', "%6.3f"%np.mean(data))
print('Variância de X:', "%6.3f"%np.var(data))
print ('-' * 20)
# Out:
# X segue uma distribuição LogGamma
# Média de X: 1430.950
# Variância de X: 75.965
# --------------------

# %%
for n in [2, 4, 10, 30, 50, 100]:
    sampling = loggamma.rvs(0.08,1440,0.7,size=(100000,n))
    mean_of_sample = np.mean(sampling,1)
    mean_of_mean = np.mean(mean_of_sample)
    dp_of_mean = np.std(mean_of_sample,ddof=1)
    plt.figure()
    plt.hist(mean_of_sample,bins=20,normed=True)
    x = np.linspace(1390,1450,100)
    y = norm.pdf(x,loc=mean_of_mean,scale=dp_of_mean)
    plt.plot(x,y,'r')
    plt.title('Tamanho da amostra: n='+str(n))
    print('Tamanho da amostra: n=',n)
    print('Média das médias amostrais:', "%6.3f"%mean_of_mean)
    print('Variância das médias amostrais:', "%6.3f"%dp_of_mean**2)
    print ('-' * 20)
# Out:
# Tamanho da amostra: n= 2
# Média das médias amostrais: 1430.911
# Variância das médias amostrais: 38.875
# --------------------
# Tamanho da amostra: n= 4
# Média das médias amostrais: 1430.929
# Variância das médias amostrais: 19.405
# --------------------
# Tamanho da amostra: n= 10
# Média das médias amostrais: 1430.916
# Variância das médias amostrais:  7.771
# --------------------
# Tamanho da amostra: n= 30
# Média das médias amostrais: 1430.937
# Variância das médias amostrais:  2.580
# --------------------
# Tamanho da amostra: n= 50
# Média das médias amostrais: 1430.930
# Variância das médias amostrais:  1.548
# --------------------
# Tamanho da amostra: n= 100
# Média das médias amostrais: 1430.938
# Variância das médias amostrais:  0.767
# --------------------

# %% [markdown]
# ___
# ## Distribuição da Média Amostral a partir de X com distribuição Normal

# %%
x = np.linspace(0,40,100)
y = norm.pdf(x,20,4)
plt.plot(x,y)
plt.axvline(20, color='r')
data = norm.rvs(20,4, size=100000)
plt.hist(data, bins=20, normed=True)
print('X segue uma distribuição Normal')
print('Média de X:', "%6.3f"%np.mean(data))
print('Variância de X:', "%6.3f"%np.var(data))
print ('-' * 20)
# Out:
# X segue uma distribuição Normal
# Média de X: 19.978
# Variância de X: 16.082
# --------------------

# %% [markdown]
# **Construção da distribuição da Média Amostral alterando tamanho amostral n**

# %%
for n in [2, 4, 10, 30, 50, 100]:
    sampling = norm.rvs(20,4,size=(100000,n))
    mean_of_sample = np.mean(sampling,1)
    mean_of_mean = np.mean(mean_of_sample)
    dp_of_mean = np.std(mean_of_sample,ddof=1)
    plt.figure()
    plt.hist(mean_of_sample,bins=20,normed=True)
    x = np.linspace(0,40,100)
    y = norm.pdf(x,loc=mean_of_mean,scale=dp_of_mean)
    plt.plot(x,y,'r')
    plt.title('Tamanho da amostra: n='+str(n))
    print('Tamanho da amostra: n=',n)
    print('Média das médias amostrais:', "%6.3f"%mean_of_mean)
    print('Variância das médias amostrais:', "%6.3f"%dp_of_mean**2)
    print ('-' * 20)

# %% [markdown]
# ## Atividade
#
# Usando resultados teóricos ou programação, calcule n de modo que $95%$ das médias amostrais fiquem a uma distância de no máximo 0.1 desvios padrões da média populacional.  Obtenha o resultado para todas as distribuições usadas como exemplo (norm, gamma, uniform, loggamma:)
